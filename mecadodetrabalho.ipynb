# %% [markdown]
# <a href="https://colab.research.google.com/github/priscilanasciment0/TESTE/blob/main/mecadodetrabalho.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import matplotlib.ticker as mticker
from matplotlib.ticker import FuncFormatter
import plotly.graph_objects as go
import seaborn as sns

# %%
from matplotlib.pyplot import rcParams
rcParams['figure.figsize']=15,6

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Taxa de desocupação - Alagoas/Brasil - 2019/2025

# %%
df = pd.read_excel('/content/drive/MyDrive/Boletim de Conjuntura/Dados Boletim/Mercado de trabalho/1T2025_mercadotrabalho.xlsx',
                   sheet_name='tabela4099', skiprows=1)

df.head()
# Out:
#            Trimestre  Brasil  Alagoas
# 0  1º trimestre 2019    12.8     16.2
# 1  2º trimestre 2019    12.1     14.9
# 2  3º trimestre 2019    11.9     15.6
# 3  4º trimestre 2019    11.1     13.8
# 4  1º trimestre 2020    12.4     16.7

# %%
df.plot(
    x="Trimestre",
    y=["Brasil", "Alagoas"],
    marker="o",
    figsize=(12, 5),
    color=["tab:blue", "navy"]
)

plt.title("Taxa de desocupação - Alagoas/Brasil - 2019/2025")
plt.xlabel("Trimestre")
plt.ylabel("Taxa de Desocupação (%)")
plt.xticks(rotation=45)
plt.legend()
plt.grid(False)

plt.tight_layout()
plt.show()

# %%
ax = df.plot(
    x="Trimestre",
    y=["Brasil", "Alagoas"],
    marker="o",
    figsize=(12, 5),
    color=["tab:blue", "navy"]
)

# Adiciona os rótulos(valores) em cada ponto
for line in ax.get_lines():
    for x, y in zip(line.get_xdata(), line.get_ydata()):
        ax.text(x, y + 0.2, f"{y:.1f}", ha='center', fontsize=9)

plt.title("Taxa de desocupação - Alagoas/Brasil - 2019/2025")
plt.xlabel("Trimestre")
plt.ylabel("Taxa de Desocupação (%)")
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Percentual de pessoas desalentadas 2023-2025

# %%
df1 = pd.read_excel('/content/drive/MyDrive/Boletim de Conjuntura/Dados Boletim/Mercado de trabalho/1T2025_mercadotrabalho.xlsx',
                   sheet_name='tabela6813', skiprows = 1)

#Tabela 6813 - Percentual de pessoas desalentadas na população - Alagoas/Nordeste/Brasil - 2023/2025
df1.head()
# Out:
#            Trimestre  Brasil  Nordeste  Alagoas
# 0  2º trimestre 2023     3.3       8.3     12.2
# 1  3º trimestre 2023     3.1       8.0     11.0
# 2  4º trimestre 2023     3.1       7.9      9.9
# 3  1º trimestre 2024     3.2       7.9     10.0
# 4  2º trimestre 2024     2.9       7.1      9.5

# %%
df1.plot(
    x='Trimestre',
    kind='bar',
    figsize=(10, 6),
    color=['darkblue', 'dodgerblue', 'royalblue']
)
# Adiciona os rótulos (valores) em cima de cada barra
#for container in x.containers: x.bar_label(container, fmt='%.1f', padding=3)

plt.title('Percentual de pessoas desalentadas na população - Alagoas/Nordeste/Brasil - 2023 a 2025')
plt.ylabel('(%)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.grid(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Caged - Setores 1º Tri 2025

# %%
df2 = pd.read_excel('/content/drive/MyDrive/Boletim de Conjuntura/Dados Boletim/Mercado de trabalho/1T2025_mercadotrabalho.xlsx',
                   sheet_name='caged')
df2.head()
# Out:
#           Setor  SALDO 1T/25
# 0      Serviços         2595
# 1    Construção          838
# 2      Comércio         -589
# 3  Agropecuária        -2476
# 4     Indústria       -12382

# %%
df2.plot(
    x='Setor',
    y='SALDO 1T/25',
    kind='bar',
    figsize=(10, 6),
    color=['cornflowerblue'],
    legend = False
)

plt.title('Saldo de empregos por atividade em Alagoas - 1º Trimeste de 2025')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()

# %%
ax = df2.plot(
    x='Setor',
    y='SALDO 1T/25',
    kind='bar',
    figsize=(10, 6),
    color='cornflowerblue',
    legend=False
)

plt.title('Saldo de empregos por atividade em Alagoas - 1º Trimestre de 2025')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.axhline(0, color='black', linewidth=1) # Adicionar linha no zero
for container in ax.containers: ax.bar_label(container, fmt='%.0f', label_type='edge', padding=3) # Adicionar rótulos

plt.tight_layout()
plt.show()
